# %%
def df(x,y):
    return y
x0 = 0
y0 = 1
h = .05
h2 = .1
h3 = .2
end = 1
x = [x0]
x2 = [x0]
x3 = [x0]
y = [y0]
y2 = [y0]
y3 = [y0]
for i in range(int(1/h)):
    x.append(h*i+h)
    y.append(y[i]+h*df(x[i],y[i]))
for i in range(int(1/h2)):
    x2.append(h2*i+h2)
    y2.append(y2[i]+h2*df(x2[i],y2[i]))
for i in range(int(1/h3)):
    x3.append(h3*i+h3)
    y3.append(y3[i]+h3*df(x3[i],y3[i]))

# %% [markdown]
# # Making the graph

# %%
import matplotlib.pyplot as plt
plt.plot(x,y,label="step size is .05")
plt.plot(x2,y2,label="step size is .1")
plt.plot(x3,y3,label="step size is .2")
plt.legend()
plt.show()

# %% [markdown]
# As the step size decreases, the approximation gets closer to the exact value.
